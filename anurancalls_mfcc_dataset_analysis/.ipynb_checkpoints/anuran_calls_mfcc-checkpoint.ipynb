# %% [markdown]
# # 1. Multi-class and Multi-Label Classification Using Support Vector Machines

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from tabulate import tabulate
import statistics

# %% [markdown]
# ### (a) Download the Anuran Calls (MFCCs) Data Set from: https://archive.ics.uci.edu/ml/datasets/Anuran+Calls+%28MFCCs%29. Choose 70% of the data randomly as the training set.

# %%
data = pd.read_csv("../AnuranCalls/Frogs_MFCCs.csv")

# %%
train = data.sample(frac = 0.7, random_state = 42)
test = data.drop(train.index)

train.reset_index(drop = True, inplace = True)
test.reset_index(drop = True, inplace = True)

X_train = train.iloc[:, :22]
y_train = train.iloc[:, 22:-1]

X_test = test.iloc[:, :22]
y_test = test.iloc[:, 22:-1]

# %% [markdown]
# ### (b) Each instance has three labels: Families, Genus, and Species. Each of the labels has multiple classes. We wish to solve a multi-class and multi-label problem. One of the most important approaches to multi-label classification is to train a classifier for each label (binary relevance).

# %% [markdown]
# #### (i) Research exact match and hamming score/ loss methods for evaluating multilabel classification and use them in evaluating the classifiers in this problem.
#
# Hamming loss -
# It is computed as fraction of labels that are mislabelled.
#
# Hamming score -
# It is computed as fraction of labels that are correctly labelled.
#
# Exact Match -
# It checks if all labels for a data point are correct or not. If all are correct, only then classification is considered as correct.
#
# Hamming Distance -
# How many classifications do not match for each data point. Bit comparison can be done here.

# %%
def hamming_loss_function(y_test, y_pred):
    y_test['family_mismatch'] = np.where(y_test['Family'] != y_pred['Family'], 1, 0)
    y_test['genus_mismatch'] = np.where(y_test['Genus'] != y_pred['Genus'], 1, 0)
    y_test['species_mismatch'] = np.where(y_test['Species'] != y_pred['Species'], 1, 0)
    
    sum_val = 0
    sum_val += y_test["family_mismatch"].sum()
    sum_val += y_test["genus_mismatch"].sum()
    sum_val += y_test["species_mismatch"].sum()
    return (sum_val/(3*len(y_test)))

# %%
def exact_match(y_test, y_pred):
    y_test["matches"]=(y_test['Family']==y_pred['Family'])&(y_test['Genus']==y_pred['Genus'])&(y_test['Species']==y_pred['Species'])
    y_test["matches"] = y_test['matches'].astype(int)
    sum_val = 0
    sum_val += y_test["matches"].sum()
    return (sum_val/len(y_test))

# %% [markdown]
# #### (ii) Train a SVM for each of the labels, using Gaussian kernels and one versus all classifiers. Determine the weight of the SVM penalty and the width of the Gaussian Kernel using 10 fold cross validation. You are welcome to try to solve the problem with both standardized 2 and raw attributes and report the results.

# %% [markdown]
# ##### RAW Data

# %%
svm = make_pipeline(SVC(kernel = 'rbf', decision_function_shape = 'ovr'))

params = {}
params["svc__C"] = [1e-3, 1e-2, 1e-1, 1, 1e+1, 1e+2, 1e+3]
params["svc__gamma"] = np.linspace(0.1, 2, 5).tolist()

grid_search = GridSearchCV(estimator = svm, param_grid = params, cv = 10)

# %%
grid_result_family = grid_search.fit(X_train, y_train["Family"])
print("Best Train Accuracy: %f using %s" % (grid_result_family.best_score_, grid_result_family.best_params_))
print("Best Train Error: %f" % (1-grid_result_family.best_score_))
test_score = grid_result_family.best_estimator_.score(X_test, y_test["Family"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_family.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_family = grid_result_family.best_estimator_.predict(X_train)
y_pred_family = grid_result_family.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.992654 using {'svc__C': 10.0, 'svc__gamma': 2.0}
# Best Train Error: 0.007346
# Best Test Accuracy: 0.992589 using {'svc__C': 10.0, 'svc__gamma': 2.0}
# Best Test Error: 0.007411

# %%
grid_result_genus = grid_search.fit(X_train, y_train["Genus"])
print("Best Train Accuracy: %f using %s" % (grid_result_genus.best_score_, grid_result_genus.best_params_))
print("Best Train Error: %f" % (1-grid_result_genus.best_score_))
test_score = grid_result_genus.best_estimator_.score(X_test, y_test["Genus"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_genus.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_genus = grid_result_genus.best_estimator_.predict(X_train)
y_pred_genus = grid_result_genus.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.991660 using {'svc__C': 10.0, 'svc__gamma': 2.0}
# Best Train Error: 0.008340
# Best Test Accuracy: 0.991200 using {'svc__C': 10.0, 'svc__gamma': 2.0}
# Best Test Error: 0.008800

# %%
grid_result_species = grid_search.fit(X_train, y_train["Species"])
print("Best Train Accuracy: %f using %s" % (grid_result_species.best_score_, grid_result_species.best_params_))
print("Best Train Error: %f" % (1-grid_result_species.best_score_))
test_score = grid_result_species.best_estimator_.score(X_test, y_test["Species"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_species.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_species = grid_result_species.best_estimator_.predict(X_train)
y_pred_species = grid_result_species.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.991263 using {'svc__C': 10.0, 'svc__gamma': 1.525}
# Best Train Error: 0.008737
# Best Test Accuracy: 0.989347 using {'svc__C': 10.0, 'svc__gamma': 1.525}
# Best Test Error: 0.010653

# %%
y_pred_train = pd.concat([pd.Series(y_pred_train_family), pd.Series(y_pred_train_genus), pd.Series(y_pred_train_species)], axis=1, sort=False)
y_pred_train.rename(columns={0: "Family", 1: "Genus", 2: "Species"}, errors="raise", inplace = True)

y_pred = pd.concat([pd.Series(y_pred_family), pd.Series(y_pred_genus), pd.Series(y_pred_species)], axis=1, sort=False)
y_pred.rename(columns={0: "Family", 1: "Genus", 2: "Species"}, errors="raise", inplace = True)

# %% [markdown]
# #### Hamming Score/Loss

# %%
print("Train Scores")
loss = hamming_loss_function(y_train, y_pred_train)
print("Hamming Loss obtained: " + str(loss))
print("Hamming Score obtained: " + str(1-loss))

print("Test Scores")
loss = hamming_loss_function(y_test, y_pred)
print("Hamming Loss obtained: " + str(loss))
print("Hamming Score obtained: " + str(1-loss))
# Out:
# Train Scores
# Hamming Loss obtained: 0.00013238019592268997
# Hamming Score obtained: 0.9998676198040773
# Test Scores
# Hamming Loss obtained: 0.00895476300756523
# Hamming Score obtained: 0.9910452369924347

# %% [markdown]
# #### Exact Match Score/Loss

# %%
print("Train Scores")
exact_match_score = exact_match(y_train, y_pred_train)
print("Exact match Loss obtained: " + str(1-exact_match_score))
print("Exact match Score obtained: " + str(exact_match_score))

print("Test Scores")
exact_match_score = exact_match(y_test, y_pred)
print("Exact match Loss obtained: " + str(1-exact_match_score))
print("Exact match Score obtained: " + str(exact_match_score))
# Out:
# Train Scores
# Exact match Loss obtained: 0.0003971405877680745
# Exact match Score obtained: 0.9996028594122319
# Test Scores
# Exact match Loss obtained: 0.011579434923575715
# Exact match Score obtained: 0.9884205650764243

# %% [markdown]
# ##### Standardized Data

# %%
svm = make_pipeline(StandardScaler(), SVC(kernel = 'rbf', decision_function_shape = 'ovr'))

params = {}
params["svc__C"] = [1e-3, 1e-2, 1e-1, 1, 1e+1, 1e+2, 1e+3]
params["svc__gamma"] = np.linspace(0.1, 2, 5).tolist()

grid_search = GridSearchCV(estimator = svm, param_grid = params, cv = 10)

# %%
grid_result_family = grid_search.fit(X_train, y_train["Family"])
print("Best Train Accuracy: %f using %s" % (grid_result_family.best_score_, grid_result_family.best_params_))
print("Best Train Error: %f" % (1-grid_result_family.best_score_))
test_score = grid_result_family.best_estimator_.score(X_test, y_test["Family"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_family.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_family = grid_result_family.best_estimator_.predict(X_train)
y_pred_family = grid_result_family.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.989871 using {'svc__C': 10.0, 'svc__gamma': 0.1}
# Best Train Error: 0.010129
# Best Test Accuracy: 0.989810 using {'svc__C': 10.0, 'svc__gamma': 0.1}
# Best Test Error: 0.010190

# %%
grid_result_genus = grid_search.fit(X_train, y_train["Genus"])
print("Best Train Accuracy: %f using %s" % (grid_result_genus.best_score_, grid_result_genus.best_params_))
print("Best Train Error: %f" % (1-grid_result_genus.best_score_))
test_score = grid_result_genus.best_estimator_.score(X_test, y_test["Genus"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_genus.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_genus = grid_result_genus.best_estimator_.predict(X_train)
y_pred_genus = grid_result_genus.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.986696 using {'svc__C': 10.0, 'svc__gamma': 0.1}
# Best Train Error: 0.013304
# Best Test Accuracy: 0.987957 using {'svc__C': 10.0, 'svc__gamma': 0.1}
# Best Test Error: 0.012043

# %%
grid_result_species = grid_search.fit(X_train, y_train["Species"])
print("Best Train Accuracy: %f using %s" % (grid_result_species.best_score_, grid_result_species.best_params_))
print("Best Train Error: %f" % (1-grid_result_species.best_score_))
test_score = grid_result_species.best_estimator_.score(X_test, y_test["Species"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_species.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_species = grid_result_species.best_estimator_.predict(X_train)
y_pred_species = grid_result_species.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.984710 using {'svc__C': 10.0, 'svc__gamma': 0.1}
# Best Train Error: 0.015290
# Best Test Accuracy: 0.986105 using {'svc__C': 10.0, 'svc__gamma': 0.1}
# Best Test Error: 0.013895

# %%
y_pred_train = pd.concat([pd.Series(y_pred_train_family), pd.Series(y_pred_train_genus), pd.Series(y_pred_train_species)], axis=1, sort=False)
y_pred_train.rename(columns={0: "Family", 1: "Genus", 2: "Species"}, errors="raise", inplace = True)

y_pred = pd.concat([pd.Series(y_pred_family), pd.Series(y_pred_genus), pd.Series(y_pred_species)], axis=1, sort=False)
y_pred.rename(columns={0: "Family", 1: "Genus", 2: "Species"}, errors="raise", inplace = True)

# %% [markdown]
# #### Hamming Score/Loss

# %%
print("Train Scores")
loss = hamming_loss_function(y_train, y_pred_train)
print("Hamming Loss obtained: " + str(loss))
print("Hamming Score obtained: " + str(1-loss))

print("Test Scores")
loss = hamming_loss_function(y_test, y_pred)
print("Hamming Loss obtained: " + str(loss))
print("Hamming Score obtained: " + str(1-loss))
# Out:
# Train Scores
# Hamming Loss obtained: 0.0
# Hamming Score obtained: 1.0
# Test Scores
# Hamming Loss obtained: 0.012042612320518759
# Hamming Score obtained: 0.9879573876794813

# %% [markdown]
# #### Exact Match Score/Loss

# %%
print("Train Scores")
exact_match_score = exact_match(y_train, y_pred_train)
print("Exact match Loss obtained: " + str(1-exact_match_score))
print("Exact match Score obtained: " + str(exact_match_score))

print("Test Scores")
exact_match_score = exact_match(y_test, y_pred)
print("Exact match Loss obtained: " + str(1-exact_match_score))
print("Exact match Score obtained: " + str(exact_match_score))
# Out:
# Train Scores
# Exact match Loss obtained: 0.0
# Exact match Score obtained: 1.0
# Test Scores
# Exact match Loss obtained: 0.016674386289949106
# Exact match Score obtained: 0.9833256137100509

# %% [markdown]
# #### Report Results
#
# | Model               | Data                | Hamming Loss | Hamming Score | Exact Match Loss | Exact Match Score |
# |---------------------|---------------------|--------------|---------------|------------------|-------------------|
# | SVM - Gaussian, OVR | Raw Train           | 0.00013      | 0.99987       | 0.00039          | 0.99960           |
# | SVM - Gaussian, OVR | Raw Test            | 0.00895      | 0.99104       | 0.01157          | 0.98842           |
# | SVM - Gaussian, OVR | Standardized Train  | 0.0          | 1.0           | 0.0              | 1.0               |
# | SVM - Gaussian, OVR | Standardized Test   | 0.01204      | 0.98796       | 0.01667          | 0.98333           |
#
# We notice that exact match loss is higher than Hamming loss. This is because exact match considers a prediction is wrong even if one of the 3 labels predicted is wrong.
#
# We can also see that the SVM on raw data has outperformed svm on standardized data on test data. But on train data, svm on standardized data has performed better. This could possibly be result of overfitting train data which led it to not be able to generalize well on test data.

# %% [markdown]
# #### (iii) Repeat 1(b)ii with L1-penalized SVMs. Remember to standardize the attributes. Determine the weight of the SVM penalty using 10 fold cross validation.

# %%
svm_l1 = make_pipeline(StandardScaler(), LinearSVC(random_state=42, max_iter = 10000, penalty = 'l1', dual = False))
params = {}
params["linearsvc__C"] = [1e-3, 1e-2, 1e-1, 1, 1e+1, 1e+2, 1e+3]
grid_search = GridSearchCV(estimator = svm_l1, param_grid = params, cv = 10)

# %%
grid_result_family = grid_search.fit(X_train, y_train["Family"])
print("Best Train Accuracy: %f using %s" % (grid_result_family.best_score_, grid_result_family.best_params_))
print("Best Train Error: %f" % (1-grid_result_family.best_score_))
test_score = grid_result_family.best_estimator_.score(X_test, y_test["Family"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_family.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_family = grid_result_family.best_estimator_.predict(X_train)
y_pred_family = grid_result_family.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.932493 using {'linearsvc__C': 1}
# Best Train Error: 0.067507
# Best Test Accuracy: 0.941176 using {'linearsvc__C': 1}
# Best Test Error: 0.058824

# %%
grid_result_genus = grid_search.fit(X_train, y_train["Genus"])
print("Best Train Accuracy: %f using %s" % (grid_result_genus.best_score_, grid_result_genus.best_params_))
print("Best Train Error: %f" % (1-grid_result_genus.best_score_))
test_score = grid_result_genus.best_estimator_.score(X_test, y_test["Genus"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_genus.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_genus = grid_result_genus.best_estimator_.predict(X_train)
y_pred_genus = grid_result_genus.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.950162 using {'linearsvc__C': 10.0}
# Best Train Error: 0.049838
# Best Test Accuracy: 0.956925 using {'linearsvc__C': 10.0}
# Best Test Error: 0.043075

# %%
grid_result_species = grid_search.fit(X_train, y_train["Species"])
print("Best Train Accuracy: %f using %s" % (grid_result_species.best_score_, grid_result_species.best_params_))
print("Best Train Error: %f" % (1-grid_result_species.best_score_))
test_score = grid_result_species.best_estimator_.score(X_test, y_test["Species"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_species.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_species = grid_result_species.best_estimator_.predict(X_train)
y_pred_species = grid_result_species.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.956913 using {'linearsvc__C': 10.0}
# Best Train Error: 0.043087
# Best Test Accuracy: 0.956925 using {'linearsvc__C': 10.0}
# Best Test Error: 0.043075

# %%
y_pred_train = pd.concat([pd.Series(y_pred_train_family), pd.Series(y_pred_train_genus), pd.Series(y_pred_train_species)], axis=1, sort=False)
y_pred_train.rename(columns={0: "Family", 1: "Genus", 2: "Species"}, errors="raise", inplace = True)

y_pred = pd.concat([pd.Series(y_pred_family), pd.Series(y_pred_genus), pd.Series(y_pred_species)], axis=1, sort=False)
y_pred.rename(columns={0: "Family", 1: "Genus", 2: "Species"}, errors="raise", inplace = True)

# %% [markdown]
# #### Hamming Score/Loss

# %%
print("Train Scores")
loss = hamming_loss_function(y_train, y_pred_train)
print("Hamming Loss obtained: " + str(loss))
print("Hamming Score obtained: " + str(1-loss))

print("Test Scores")
loss = hamming_loss_function(y_test, y_pred)
print("Hamming Loss obtained: " + str(loss))
print("Hamming Score obtained: " + str(1-loss))
# Out:
# Train Scores
# Hamming Loss obtained: 0.05003971405877681
# Hamming Score obtained: 0.9499602859412232
# Test Scores
# Hamming Loss obtained: 0.04832484174772271
# Hamming Score obtained: 0.9516751582522773

# %% [markdown]
# #### Exact Match Score/Loss

# %%
print("Train Scores")
exact_match_score = exact_match(y_train, y_pred_train)
print("Exact match Loss obtained: " + str(1-exact_match_score))
print("Exact match Score obtained: " + str(exact_match_score))

print("Test Scores")
exact_match_score = exact_match(y_test, y_pred)
print("Exact match Loss obtained: " + str(1-exact_match_score))
print("Exact match Score obtained: " + str(exact_match_score))
# Out:
# Train Scores
# Exact match Loss obtained: 0.08200953137410638
# Exact match Score obtained: 0.9179904686258936
# Test Scores
# Exact match Loss obtained: 0.08244557665585917
# Exact match Score obtained: 0.9175544233441408

# %% [markdown]
# #### Report Results
#
# | Model                 |   Data   |   Hamming Loss   |   Hamming Score   |   Exact Match Loss  | Exact Match Score  |
# |-----------------------|----------|------------------|-------------------|---------------------|--------------------|
# | SVM - L1 Penalized    |  Train   | 0.05004          | 0.94996           | 0.08200             | 0.91799            |
# | SVM - L1 Penalized    |  Test    | 0.04832          | 0.95168           | 0.08245             | 0.91755            |
#
# The SVM model with L1 penalization has performed a bit lower than SVM with Gaussian Kernel. The loss obtained are higher than previous one.
#
# We notice that exact match loss is higher than Hamming loss. This is because exact match considers a prediction is wrong even if one of the 3 labels predicted is wrong.
#
# sklearn LinearSVC function by default uses the one vs rest logic.

# %% [markdown]
# #### (iv) Repeat 1(b)iii by using SMOTE or any other method you know to remedy class imbalance. Report your conclusions about the classifiers you trained.

# %%
svm_l1 = imbpipeline(steps = [['smote', SMOTE(random_state=11)],
                              ['standardize', StandardScaler()],
                              ['classifier', 
                               LinearSVC(random_state=42, max_iter = 1000000, penalty = 'l1', dual = False)]])

params = {}
params["classifier__C"] = [1e-3, 1e-2, 1e-1, 1, 1e+1, 1e+2, 1e+3]
grid_search = GridSearchCV(estimator = svm_l1, param_grid = params, cv = 10)

# %%
grid_result_family = grid_search.fit(X_train, y_train["Family"])
print("Best Train Accuracy: %f using %s" % (grid_result_family.best_score_, grid_result_family.best_params_))
print("Best Train Error: %f" % (1-grid_result_family.best_score_))
test_score = grid_result_family.best_estimator_.score(X_test, y_test["Family"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_family.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_family = grid_result_family.best_estimator_.predict(X_train)
y_pred_family = grid_result_family.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.914821 using {'classifier__C': 100.0}
# Best Train Error: 0.085179
# Best Test Accuracy: 0.925428 using {'classifier__C': 100.0}
# Best Test Error: 0.074572

# %%
grid_result_genus = grid_search.fit(X_train, y_train["Genus"])
print("Best Train Accuracy: %f using %s" % (grid_result_genus.best_score_, grid_result_genus.best_params_))
print("Best Train Error: %f" % (1-grid_result_genus.best_score_))
test_score = grid_result_genus.best_estimator_.score(X_test, y_test["Genus"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_genus.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_genus = grid_result_genus.best_estimator_.predict(X_train)
y_pred_genus = grid_result_genus.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.913234 using {'classifier__C': 10.0}
# Best Train Error: 0.086766
# Best Test Accuracy: 0.924039 using {'classifier__C': 10.0}
# Best Test Error: 0.075961

# %%
grid_result_species = grid_search.fit(X_train, y_train["Species"])
print("Best Train Accuracy: %f using %s" % (grid_result_species.best_score_, grid_result_species.best_params_))
print("Best Train Error: %f" % (1-grid_result_species.best_score_))
test_score = grid_result_species.best_estimator_.score(X_test, y_test["Species"])
print("Best Test Accuracy: %f using %s" % (test_score, grid_result_species.best_params_))
print("Best Test Error: %f" % (1-test_score))
y_pred_train_species = grid_result_species.best_estimator_.predict(X_train)
y_pred_species = grid_result_species.best_estimator_.predict(X_test)
# Out:
# Best Train Accuracy: 0.953339 using {'classifier__C': 100.0}
# Best Train Error: 0.046661
# Best Test Accuracy: 0.957388 using {'classifier__C': 100.0}
# Best Test Error: 0.042612

# %%
y_pred_train = pd.concat([pd.Series(y_pred_train_family), pd.Series(y_pred_train_genus), pd.Series(y_pred_train_species)], axis=1, sort=False)
y_pred_train.rename(columns={0: "Family", 1: "Genus", 2: "Species"}, errors="raise", inplace = True)

y_pred = pd.concat([pd.Series(y_pred_family), pd.Series(y_pred_genus), pd.Series(y_pred_species)], axis=1, sort=False)
y_pred.rename(columns={0: "Family", 1: "Genus", 2: "Species"}, errors="raise", inplace = True)

# %% [markdown]
# #### Hamming Score/Loss for Test Data

# %%
print("Train Scores")
loss = hamming_loss_function(y_train, y_pred_train)
print("Hamming Loss obtained: " + str(loss))
print("Hamming Score obtained: " + str(1-loss))

print("Test Scores")
loss = hamming_loss_function(y_test, y_pred)
print("Hamming Loss obtained: " + str(loss))
print("Hamming Score obtained: " + str(1-loss))
# Out:
# Train Scores
# Hamming Loss obtained: 0.06817580090018534
# Hamming Score obtained: 0.9318241990998146
# Test Scores
# Hamming Loss obtained: 0.06438165817508106
# Hamming Score obtained: 0.935618341824919

# %% [markdown]
# #### Exact Match Score/Loss for Test Data

# %%
print("Train Scores")
exact_match_score = exact_match(y_train, y_pred_train)
print("Exact match Loss obtained: " + str(1-exact_match_score))
print("Exact match Score obtained: " + str(exact_match_score))

print("Test Scores")
exact_match_score = exact_match(y_test, y_pred)
print("Exact match Loss obtained: " + str(1-exact_match_score))
print("Exact match Score obtained: " + str(exact_match_score))
# Out:
# Train Scores
# Exact match Loss obtained: 0.13602065131056396
# Exact match Score obtained: 0.863979348689436
# Test Scores
# Exact match Loss obtained: 0.12459471977767489
# Exact match Score obtained: 0.8754052802223251

# %% [markdown]
# #### Report Results
#
# | Model                 |   Data   |   Hamming Loss   |   Hamming Score   |   Exact Match Loss  | Exact Match Score  |
# |-----------------------|----------|------------------|-------------------|---------------------|--------------------|
# | SVM-L1 Penalty, Smote |  Train   | 0.06818          | 0.93182           | 0.13602             | 0.86398            |
# | SVM-L1 Penalty, Smote |  Test    | 0.06438          | 0.93562           | 0.12459             | 0.87541            |
#
# The SVM model with L1 penalization and Smote has performed lower compared to the two SVM models tried before. The test Hamming score is 93% and exact match score is as low as 87%
#
# We notice that exact match loss is higher than Hamming loss. This is because exact match considers a prediction is wrong even if one of the 3 labels predicted is wrong.
#
# sklearn LinearSVC function by default uses the one vs rest logic.

# %% [markdown]
# # 2. K-Means Clustering on a Multi-Class and Multi-Label Data Set

# %% [markdown]
# ### Monte-Carlo Simulation: Perform the following procedures 50 times, and report the average and standard deviation of the 50 Hamming Distances that you calculate.

# %%
def hamming_distance_function(y_test, y_pred):
    y_test['family_mismatch'] = np.where(y_test['Family'] != y_pred['Family'], 1, 0)
    y_test['genus_mismatch'] = np.where(y_test['Genus'] != y_pred['Genus'], 1, 0)
    y_test['species_mismatch'] = np.where(y_test['Species'] != y_pred['Species'], 1, 0)
    
    col_list = ["family_mismatch", "genus_mismatch", "species_mismatch"]
    y_test['hamming_distance'] = y_test[col_list].sum(axis=1)
    sum_val = y_test["hamming_distance"].sum()
    return (sum_val/(len(y_test))), y_test['hamming_distance'].std()

# %% [markdown]
# ### (a) Use k-means clustering on the whole Anuran Calls (MFCCs) Data Set (do not split the data into train and test, as we are not performing supervised learning in this exercise). Choose k ∈ {1, 2, . . . , 50} automatically based on one of the methods provided in the slides (CH or Gap Statistics or scree plots or Silhouettes) or any other method you know

# %%
X = data.iloc[:, :22]
y = data.iloc[:, 22:-1]

# %%
def kmeans_silhouette():
    ks_pair = {}
    for n_cluster in range(1, 51):
        kmeans = KMeans(n_clusters=n_cluster).fit(X)
        label = kmeans.labels_
        sil_coeff = 0
        if n_cluster != 1:
            sil_coeff = silhouette_score(X, label, metric='euclidean')
        print("For n_clusters={}, The Silhouette Coefficient is {}".format(n_cluster, sil_coeff))
        ks_pair[n_cluster] = sil_coeff
    return (max(ks_pair, key=ks_pair.get),max(ks_pair.values()))

def find_best_k_refit():
    k, sil_score = kmeans_silhouette()
    print("Best k is " + str(k) + " based on highest Silhouette coefficient score: " + str(sil_score))
    kmeans = KMeans(n_clusters=k).fit(X)
    return kmeans

# %% [markdown]
# ### (b) In each cluster, determine which family is the majority by reading the true labels. Repeat for genus and species.

# %%
def cluster_majority():
    kmeans = find_best_k_refit()
    y["kmeans_label"] = pd.Series(kmeans.labels_)
    y_family_label = y[["Family", "kmeans_label"]]
    kmeans_label_groupedby = y_family_label.groupby(['kmeans_label'])['Family'].value_counts().rename('kmeans_family').reset_index().drop_duplicates('kmeans_label')
    print("Family cluster majority\n")
    print(kmeans_label_groupedby.to_markdown())
    print("\n")
    kmeans_label_groupedby.drop(["kmeans_family"], axis = 1, inplace = True)
    joined_fam = y_family_label.join(kmeans_label_groupedby.set_index('kmeans_label'), on='kmeans_label', lsuffix = "_l", rsuffix = "_r")
    y_genus_label = y[["Genus", "kmeans_label"]]
    kmeans_label_groupedby = y_genus_label.groupby(['kmeans_label'])['Genus'].value_counts().rename('kmeans_genus').reset_index().drop_duplicates('kmeans_label')
    print("Genus cluster majority\n")
    print(kmeans_label_groupedby.to_markdown())
    print("\n")
    kmeans_label_groupedby.drop(["kmeans_genus"], axis = 1, inplace = True)
    joined_gen = y_genus_label.join(kmeans_label_groupedby.set_index('kmeans_label'), on = 'kmeans_label', lsuffix = "_l", rsuffix = "_r")
    y_species_label = y[["Species", "kmeans_label"]]
    kmeans_label_groupedby = y_species_label.groupby(['kmeans_label'])['Species'].value_counts().rename('kmeans_species').reset_index().drop_duplicates('kmeans_label')
    print("Species cluster majority\n")
    print(kmeans_label_groupedby.to_markdown())
    print("\n")
    kmeans_label_groupedby.drop(["kmeans_species"], axis = 1, inplace = True)
    joined_spe = y_species_label.join(kmeans_label_groupedby.set_index('kmeans_label'), on = 'kmeans_label', lsuffix = "_l", rsuffix = "_r")
    all_joined_test = pd.concat([joined_fam["Family_l"], joined_gen["Genus_l"], joined_spe["Species_l"]], axis=1, sort=False)
    all_joined_pred = pd.concat([joined_fam["Family_r"], joined_gen["Genus_r"], joined_spe["Species_r"]], axis=1, sort=False)
    all_joined_test.rename(columns={"Family_l": "Family", "Genus_l": "Genus", "Species_l": "Species"}, errors="raise", inplace = True)
    all_joined_pred.rename(columns={"Family_r": "Family", "Genus_r": "Genus", "Species_r": "Species"}, errors="raise", inplace = True)
    return all_joined_test, all_joined_pred

# %% [markdown]
# ### (c) Now for each cluster you have a majority label triplet (family, genus, species). Calculate the average Hamming distance, Hamming score, and Hamming loss between the true labels and the labels assigned by clusters.

# %%
def kmeans_hamming(all_joined_test, all_joined_pred):
    hamming_loss = hamming_loss_function(all_joined_test, all_joined_pred)
    hamming_score = 1-hamming_loss
    hamming_dist, hamming_dist_stddev = hamming_distance_function(all_joined_test, all_joined_pred)
    print("Hamming Loss obtained: " + str(hamming_loss))
    print("Hamming Score obtained: " + str(hamming_score))
    print("Hamming Distance obtained: " + str(hamming_dist))
    print("Hamming Distance Standard Deviation obtained: " + str(hamming_dist_stddev))
    return hamming_loss, hamming_score, hamming_dist, hamming_dist_stddev

# %% [markdown]
# #### Run 50 times and find average hamming distance

# %%
hamming_loss_dict = []
hamming_score_dict = []
hamming_dist_dict = []
hamming_dist_std_dict = []
for i in range(1, 51):
    print("Monte Carlo Simulation Iteration: " + str(i))
    all_joined_test, all_joined_pred = cluster_majority()
    hamming_loss, hamming_score, hamming_dist, hamming_dist_stddev = kmeans_hamming(all_joined_test, all_joined_pred)
    hamming_loss_dict.append(hamming_loss)
    hamming_score_dict.append(hamming_score)
    hamming_dist_dict.append(hamming_dist)
    hamming_dist_std_dict.append(hamming_dist_stddev)
# Out:
# Monte Carlo Simulation Iteration: 1
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.3787509343305295
# For n_clusters=5, The Silhouette Coefficient is 0.3714828057802203
# For n_clusters=6, The Silhouette Coefficient is 0.2644444827073779
# For n_clusters=7, The Silhouette Coefficient is 0.2711094888906035
# For n_clusters=8, The Silhouette Coefficient is 0.2808269101044866
# For n_clusters=9, The Silhouette Coefficient is 0.26382411375888454
# For n_clusters=10, The Silhouette Coefficient is 0.2731030040246207
# For n_clusters=11, The Silhouette Coefficient is 0.2736414071621672
# For n_clusters=12, The Silhouette Coefficient is 0.2837375255329622
# For n_clusters=13, The Silhouette Coefficient is 0.2588879935751163
# For n_clusters=14, The Silhouette Coefficient is 0.2826271255287889
# For n_clusters=15, The Silhouette Coefficient is 0.2703980874008088
# For n_clusters=16, The Silhouette Coefficient is 0.2681337675050933
# For n_clusters=17, The Silhouette Coefficient is 0.26631287025098666
# For n_clusters=18, The Silhouette Coefficient is 0.27152473791190584
# For n_clusters=19, The Silhouette Coefficient is 0.2712713094820632
# For n_clusters=20, The Silhouette Coefficient is 0.2710658745107931
# For n_clusters=21, The Silhouette Coefficient is 0.2612864216070776
# For n_clusters=22, The Silhouette Coefficient is 0.26995295635029004
# For n_clusters=23, The Silhouette Coefficient is 0.2842022104017338
# For n_clusters=24, The Silhouette Coefficient is 0.27459185445676215
# For n_clusters=25, The Silhouette Coefficient is 0.2628369827336927
# For n_clusters=26, The Silhouette Coefficient is 0.2622071147266179
# For n_clusters=27, The Silhouette Coefficient is 0.2720057362718187
# For n_clusters=28, The Silhouette Coefficient is 0.26873311858953364
# For n_clusters=29, The Silhouette Coefficient is 0.26185466126942
# For n_clusters=30, The Silhouette Coefficient is 0.26926737261830136
# For n_clusters=31, The Silhouette Coefficient is 0.2607279291055867
# For n_clusters=32, The Silhouette Coefficient is 0.25995873202495473
# For n_clusters=33, The Silhouette Coefficient is 0.2648340976774313
# For n_clusters=34, The Silhouette Coefficient is 0.2668980694115783
# For n_clusters=35, The Silhouette Coefficient is 0.2593561875975095
# For n_clusters=36, The Silhouette Coefficient is 0.26273155638842494
# For n_clusters=37, The Silhouette Coefficient is 0.2277334407160909
# For n_clusters=38, The Silhouette Coefficient is 0.2562590547024556
# For n_clusters=39, The Silhouette Coefficient is 0.2281808746724853
# For n_clusters=40, The Silhouette Coefficient is 0.2669976772853625
# For n_clusters=41, The Silhouette Coefficient is 0.23079059026940663
# For n_clusters=42, The Silhouette Coefficient is 0.26081057120207235
# For n_clusters=43, The Silhouette Coefficient is 0.23596849532672326
# For n_clusters=44, The Silhouette Coefficient is 0.23250258865358053
# For n_clusters=45, The Silhouette Coefficient is 0.23346256153312483
# For n_clusters=46, The Silhouette Coefficient is 0.22996154309326047
# For n_clusters=47, The Silhouette Coefficient is 0.2198443439773378
# For n_clusters=48, The Silhouette Coefficient is 0.23737550999955695
# For n_clusters=49, The Silhouette Coefficient is 0.23463307543913312
# For n_clusters=50, The Silhouette Coefficient is 0.20506904200399056
# Best k is 4 based on highest Silhouette coefficient score: 0.3787509343305295
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Hylidae         |             590 |
# |  3 |              1 | Leptodactylidae |            3467 |
# |  5 |              2 | Hylidae         |            1245 |
# |  9 |              3 | Dendrobatidae   |             500 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Hypsiboas |            542 |
# |  6 |              1 | Adenomera |           3466 |
# | 11 |              2 | Hypsiboas |           1038 |
# | 19 |              3 | Ameerega  |            500 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | HypsiboasCinerascens   |              452 |
# |  8 |              1 | AdenomeraHylaedactylus |             3466 |
# | 13 |              2 | HypsiboasCordobae      |             1018 |
# | 23 |              3 | Ameeregatrivittata     |              500 |
#
#
# Hamming Loss obtained: 0.2224229789205467
# Hamming Score obtained: 0.7775770210794533
# Hamming Distance obtained: 0.66726893676164
# Hamming Distance Standard Deviation obtained: 1.206243709132836
# Monte Carlo Simulation Iteration: 2
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.3787509343305295
# For n_clusters=5, The Silhouette Coefficient is 0.3714828057802203
# For n_clusters=6, The Silhouette Coefficient is 0.23777369888715372
# For n_clusters=7, The Silhouette Coefficient is 0.260540085155543
# For n_clusters=8, The Silhouette Coefficient is 0.2808269101044866
# For n_clusters=9, The Silhouette Coefficient is 0.2765295775055931
# For n_clusters=10, The Silhouette Coefficient is 0.2731760405206378
# For n_clusters=11, The Silhouette Coefficient is 0.27183561470013773
# For n_clusters=12, The Silhouette Coefficient is 0.2720463166139206
# For n_clusters=13, The Silhouette Coefficient is 0.2769854525895776
# For n_clusters=14, The Silhouette Coefficient is 0.28390033786734087
# For n_clusters=15, The Silhouette Coefficient is 0.2703963271410436
# For n_clusters=16, The Silhouette Coefficient is 0.28286231729385103
# For n_clusters=17, The Silhouette Coefficient is 0.27335082288673096
# For n_clusters=18, The Silhouette Coefficient is 0.2639649337447734
# For n_clusters=19, The Silhouette Coefficient is 0.2634969981603363
# For n_clusters=20, The Silhouette Coefficient is 0.2661962195485269
# For n_clusters=21, The Silhouette Coefficient is 0.2717395268976261
# For n_clusters=22, The Silhouette Coefficient is 0.2814794321717496
# For n_clusters=23, The Silhouette Coefficient is 0.28430144298813576
# For n_clusters=24, The Silhouette Coefficient is 0.26614389121932935
# For n_clusters=25, The Silhouette Coefficient is 0.27042878619972194
# For n_clusters=26, The Silhouette Coefficient is 0.2632978715567911
# For n_clusters=27, The Silhouette Coefficient is 0.2606285066679747
# For n_clusters=28, The Silhouette Coefficient is 0.25593772085194855
# For n_clusters=29, The Silhouette Coefficient is 0.2569697328414395
# For n_clusters=30, The Silhouette Coefficient is 0.26343685068659006
# For n_clusters=31, The Silhouette Coefficient is 0.24574869127364374
# For n_clusters=32, The Silhouette Coefficient is 0.2666138204215234
# For n_clusters=33, The Silhouette Coefficient is 0.2700593912725693
# For n_clusters=34, The Silhouette Coefficient is 0.24564209397477474
# For n_clusters=35, The Silhouette Coefficient is 0.26304212734159704
# For n_clusters=36, The Silhouette Coefficient is 0.2617604245492425
# For n_clusters=37, The Silhouette Coefficient is 0.2581054954676307
# For n_clusters=38, The Silhouette Coefficient is 0.25932157087021956
# For n_clusters=39, The Silhouette Coefficient is 0.24052701571509047
# For n_clusters=40, The Silhouette Coefficient is 0.2591343517498227
# For n_clusters=41, The Silhouette Coefficient is 0.23833866173799126
# For n_clusters=42, The Silhouette Coefficient is 0.2336020580233955
# For n_clusters=43, The Silhouette Coefficient is 0.2422306608202896
# For n_clusters=44, The Silhouette Coefficient is 0.25184531513660763
# For n_clusters=45, The Silhouette Coefficient is 0.2624897293140569
# For n_clusters=46, The Silhouette Coefficient is 0.23834066467233045
# For n_clusters=47, The Silhouette Coefficient is 0.22774673142965604
# For n_clusters=48, The Silhouette Coefficient is 0.21291213108166687
# For n_clusters=49, The Silhouette Coefficient is 0.22934397176342294
# For n_clusters=50, The Silhouette Coefficient is 0.22975952529854923
# Best k is 4 based on highest Silhouette coefficient score: 0.3787509343305295
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Leptodactylidae |            3467 |
# |  2 |              1 | Hylidae         |            1245 |
# |  6 |              2 | Dendrobatidae   |             500 |
# |  9 |              3 | Hylidae         |             590 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Adenomera |           3466 |
# |  5 |              1 | Hypsiboas |           1038 |
# | 13 |              2 | Ameerega  |            500 |
# | 19 |              3 | Hypsiboas |            542 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | AdenomeraHylaedactylus |             3466 |
# |  5 |              1 | HypsiboasCordobae      |             1018 |
# | 15 |              2 | Ameeregatrivittata     |              500 |
# | 21 |              3 | HypsiboasCinerascens   |              452 |
#
#
# Hamming Loss obtained: 0.2224229789205467
# Hamming Score obtained: 0.7775770210794533
# Hamming Distance obtained: 0.66726893676164
# Hamming Distance Standard Deviation obtained: 1.206243709132836
# Monte Carlo Simulation Iteration: 3
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.3676927081149251
# For n_clusters=4, The Silhouette Coefficient is 0.3788646212055977
# For n_clusters=5, The Silhouette Coefficient is 0.3714828057802203
# For n_clusters=6, The Silhouette Coefficient is 0.2643012426547729
# For n_clusters=7, The Silhouette Coefficient is 0.2604467847497036
# For n_clusters=8, The Silhouette Coefficient is 0.27043178624172043
# For n_clusters=9, The Silhouette Coefficient is 0.27626823136327655
# For n_clusters=10, The Silhouette Coefficient is 0.2744214363676923
# For n_clusters=11, The Silhouette Coefficient is 0.2715367741206972
# For n_clusters=12, The Silhouette Coefficient is 0.25717364795075376
# For n_clusters=13, The Silhouette Coefficient is 0.2788087932227544
# For n_clusters=14, The Silhouette Coefficient is 0.28321461959354516
# For n_clusters=15, The Silhouette Coefficient is 0.27018316990254254
# For n_clusters=16, The Silhouette Coefficient is 0.27608970621369416
# For n_clusters=17, The Silhouette Coefficient is 0.2767627740453244
# For n_clusters=18, The Silhouette Coefficient is 0.2716026005735688
# For n_clusters=19, The Silhouette Coefficient is 0.2710516855014979
# For n_clusters=20, The Silhouette Coefficient is 0.2688898046255262
# For n_clusters=21, The Silhouette Coefficient is 0.2618542536034913
# For n_clusters=22, The Silhouette Coefficient is 0.2733495529807509
# For n_clusters=23, The Silhouette Coefficient is 0.270304367699435
# For n_clusters=24, The Silhouette Coefficient is 0.2775455481250707
# For n_clusters=25, The Silhouette Coefficient is 0.2695432777326155
# For n_clusters=26, The Silhouette Coefficient is 0.27327583476863593
# For n_clusters=27, The Silhouette Coefficient is 0.2709410909801248
# For n_clusters=28, The Silhouette Coefficient is 0.2612947512334181
# For n_clusters=29, The Silhouette Coefficient is 0.26543361061257364
# For n_clusters=30, The Silhouette Coefficient is 0.2665300242904689
# For n_clusters=31, The Silhouette Coefficient is 0.2653349003209899
# For n_clusters=32, The Silhouette Coefficient is 0.2676134409158257
# For n_clusters=33, The Silhouette Coefficient is 0.2593746748998962
# For n_clusters=34, The Silhouette Coefficient is 0.2594000012352062
# For n_clusters=35, The Silhouette Coefficient is 0.2627667637602087
# For n_clusters=36, The Silhouette Coefficient is 0.265819842102795
# For n_clusters=37, The Silhouette Coefficient is 0.26398693002002777
# For n_clusters=38, The Silhouette Coefficient is 0.25596615554223867
# For n_clusters=39, The Silhouette Coefficient is 0.23787165771918897
# For n_clusters=40, The Silhouette Coefficient is 0.24281432986417886
# For n_clusters=41, The Silhouette Coefficient is 0.24125159269697324
# For n_clusters=42, The Silhouette Coefficient is 0.23109778948717707
# For n_clusters=43, The Silhouette Coefficient is 0.24342360763880552
# For n_clusters=44, The Silhouette Coefficient is 0.2295186063093099
# For n_clusters=45, The Silhouette Coefficient is 0.2567089948346704
# For n_clusters=46, The Silhouette Coefficient is 0.22839296770983672
# For n_clusters=47, The Silhouette Coefficient is 0.2289001799158882
# For n_clusters=48, The Silhouette Coefficient is 0.24749081483868893
# For n_clusters=49, The Silhouette Coefficient is 0.2322658092562325
# For n_clusters=50, The Silhouette Coefficient is 0.23589006767669957
# Best k is 4 based on highest Silhouette coefficient score: 0.3788646212055977
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Hylidae         |             590 |
# |  3 |              1 | Leptodactylidae |            3467 |
# |  5 |              2 | Hylidae         |            1245 |
# |  9 |              3 | Dendrobatidae   |             500 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Hypsiboas |            542 |
# |  6 |              1 | Adenomera |           3466 |
# | 11 |              2 | Hypsiboas |           1038 |
# | 19 |              3 | Ameerega  |            500 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | HypsiboasCinerascens   |              452 |
# |  8 |              1 | AdenomeraHylaedactylus |             3466 |
# | 13 |              2 | HypsiboasCordobae      |             1018 |
# | 23 |              3 | Ameeregatrivittata     |              500 |
#
#
# Hamming Loss obtained: 0.2224229789205467
# Hamming Score obtained: 0.7775770210794533
# Hamming Distance obtained: 0.66726893676164
# Hamming Distance Standard Deviation obtained: 1.206243709132836
# Monte Carlo Simulation Iteration: 4
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.3787509343305295
# For n_clusters=5, The Silhouette Coefficient is 0.37149147864771287
# For n_clusters=6, The Silhouette Coefficient is 0.26447069759492176
# For n_clusters=7, The Silhouette Coefficient is 0.26016433755278856
# For n_clusters=8, The Silhouette Coefficient is 0.270316900334005
# For n_clusters=9, The Silhouette Coefficient is 0.26068760410261077
# For n_clusters=10, The Silhouette Coefficient is 0.2730242352172469
# For n_clusters=11, The Silhouette Coefficient is 0.2636892826973842
# For n_clusters=12, The Silhouette Coefficient is 0.27123778968790363
# For n_clusters=13, The Silhouette Coefficient is 0.27773740248320833
# For n_clusters=14, The Silhouette Coefficient is 0.2796163502298201
# For n_clusters=15, The Silhouette Coefficient is 0.27039500646231435
# For n_clusters=16, The Silhouette Coefficient is 0.26671166984732847
# For n_clusters=17, The Silhouette Coefficient is 0.27560839014969235
# For n_clusters=18, The Silhouette Coefficient is 0.2805061679476975
# For n_clusters=19, The Silhouette Coefficient is 0.26844321277585836
# For n_clusters=20, The Silhouette Coefficient is 0.2751611525086473
# For n_clusters=21, The Silhouette Coefficient is 0.2670885450681557
# For n_clusters=22, The Silhouette Coefficient is 0.27138390112925465
# For n_clusters=23, The Silhouette Coefficient is 0.27465073184990296
# For n_clusters=24, The Silhouette Coefficient is 0.2662165873032505
# For n_clusters=25, The Silhouette Coefficient is 0.2642998934657381
# For n_clusters=26, The Silhouette Coefficient is 0.2676485014258038
# For n_clusters=27, The Silhouette Coefficient is 0.2676906107494742
# For n_clusters=28, The Silhouette Coefficient is 0.24373003481958608
# For n_clusters=29, The Silhouette Coefficient is 0.2684441322699683
# For n_clusters=30, The Silhouette Coefficient is 0.26253821018598117
# For n_clusters=31, The Silhouette Coefficient is 0.2641189481588573
# For n_clusters=32, The Silhouette Coefficient is 0.2611438481567203
# For n_clusters=33, The Silhouette Coefficient is 0.24208749404260188
# For n_clusters=34, The Silhouette Coefficient is 0.2644255963399897
# For n_clusters=35, The Silhouette Coefficient is 0.24229663206583113
# For n_clusters=36, The Silhouette Coefficient is 0.26456940052637573
# For n_clusters=37, The Silhouette Coefficient is 0.2583173104079802
# For n_clusters=38, The Silhouette Coefficient is 0.22199671568416068
# For n_clusters=39, The Silhouette Coefficient is 0.23760463863437406
# For n_clusters=40, The Silhouette Coefficient is 0.24901895624755147
# For n_clusters=41, The Silhouette Coefficient is 0.21738693094615114
# For n_clusters=42, The Silhouette Coefficient is 0.24011460282472835
# For n_clusters=43, The Silhouette Coefficient is 0.21301834788231147
# For n_clusters=44, The Silhouette Coefficient is 0.23759072056241795
# For n_clusters=45, The Silhouette Coefficient is 0.2490960612907709
# For n_clusters=46, The Silhouette Coefficient is 0.21026730146009487
# For n_clusters=47, The Silhouette Coefficient is 0.23469799592100007
# For n_clusters=48, The Silhouette Coefficient is 0.2204246867588014
# For n_clusters=49, The Silhouette Coefficient is 0.21597169678789083
# For n_clusters=50, The Silhouette Coefficient is 0.21790981630962783
# Best k is 4 based on highest Silhouette coefficient score: 0.3787509343305295
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Leptodactylidae |            3467 |
# |  2 |              1 | Dendrobatidae   |             500 |
# |  5 |              2 | Hylidae         |            1244 |
# |  9 |              3 | Hylidae         |             591 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Adenomera |           3466 |
# |  5 |              1 | Ameerega  |            500 |
# | 11 |              2 | Hypsiboas |           1037 |
# | 19 |              3 | Hypsiboas |            543 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | AdenomeraHylaedactylus |             3466 |
# |  5 |              1 | Ameeregatrivittata     |              500 |
# | 11 |              2 | HypsiboasCordobae      |             1017 |
# | 21 |              3 | HypsiboasCinerascens   |              452 |
#
#
# Hamming Loss obtained: 0.22246930738939077
# Hamming Score obtained: 0.7775306926106093
# Hamming Distance obtained: 0.6674079221681724
# Hamming Distance Standard Deviation obtained: 1.2062244252863619
# Monte Carlo Simulation Iteration: 5
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.37867825251598397
# For n_clusters=5, The Silhouette Coefficient is 0.3714828057802203
# For n_clusters=6, The Silhouette Coefficient is 0.264008021116715
# For n_clusters=7, The Silhouette Coefficient is 0.26057116055596974
# For n_clusters=8, The Silhouette Coefficient is 0.28072632942968273
# For n_clusters=9, The Silhouette Coefficient is 0.2758610344651533
# For n_clusters=10, The Silhouette Coefficient is 0.2624061277907544
# For n_clusters=11, The Silhouette Coefficient is 0.26460303358569476
# For n_clusters=12, The Silhouette Coefficient is 0.2719715745876429
# For n_clusters=13, The Silhouette Coefficient is 0.2787322675914197
# For n_clusters=14, The Silhouette Coefficient is 0.2842257217884614
# For n_clusters=15, The Silhouette Coefficient is 0.2701770118916337
# For n_clusters=16, The Silhouette Coefficient is 0.2663029977058543
# For n_clusters=17, The Silhouette Coefficient is 0.28099165146228977
# For n_clusters=18, The Silhouette Coefficient is 0.2786637968428291
# For n_clusters=19, The Silhouette Coefficient is 0.2640260582202297
# For n_clusters=20, The Silhouette Coefficient is 0.25767937099914684
# For n_clusters=21, The Silhouette Coefficient is 0.2729780478739818
# For n_clusters=22, The Silhouette Coefficient is 0.2653777508113729
# For n_clusters=23, The Silhouette Coefficient is 0.2755792127094558
# For n_clusters=24, The Silhouette Coefficient is 0.2684773084670619
# For n_clusters=25, The Silhouette Coefficient is 0.2774955040875577
# For n_clusters=26, The Silhouette Coefficient is 0.2774665515663226
# For n_clusters=27, The Silhouette Coefficient is 0.26188658176442636
# For n_clusters=28, The Silhouette Coefficient is 0.2652063071078709
# For n_clusters=29, The Silhouette Coefficient is 0.2668157135937916
# For n_clusters=30, The Silhouette Coefficient is 0.2735781633320146
# For n_clusters=31, The Silhouette Coefficient is 0.260347897288803
# For n_clusters=32, The Silhouette Coefficient is 0.2627560762003593
# For n_clusters=33, The Silhouette Coefficient is 0.2666942057352667
# For n_clusters=34, The Silhouette Coefficient is 0.2666202013749517
# For n_clusters=35, The Silhouette Coefficient is 0.26134699934748296
# For n_clusters=36, The Silhouette Coefficient is 0.26411182748659157
# For n_clusters=37, The Silhouette Coefficient is 0.2492291539223058
# For n_clusters=38, The Silhouette Coefficient is 0.2500589009522916
# For n_clusters=39, The Silhouette Coefficient is 0.24510843205410127
# For n_clusters=40, The Silhouette Coefficient is 0.22722230685326125
# For n_clusters=41, The Silhouette Coefficient is 0.2531424244799016
# For n_clusters=42, The Silhouette Coefficient is 0.2248694575171328
# For n_clusters=43, The Silhouette Coefficient is 0.2619855913532726
# For n_clusters=44, The Silhouette Coefficient is 0.2231197727530796
# For n_clusters=45, The Silhouette Coefficient is 0.2557498404204899
# For n_clusters=46, The Silhouette Coefficient is 0.22153144011008383
# For n_clusters=47, The Silhouette Coefficient is 0.2429747218040774
# For n_clusters=48, The Silhouette Coefficient is 0.2300520679959359
# For n_clusters=49, The Silhouette Coefficient is 0.2110558140212369
# For n_clusters=50, The Silhouette Coefficient is 0.21350885533220512
# Best k is 4 based on highest Silhouette coefficient score: 0.37867825251598397
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Leptodactylidae |            3467 |
# |  2 |              1 | Hylidae         |             590 |
# |  5 |              2 | Hylidae         |            1245 |
# |  9 |              3 | Dendrobatidae   |             500 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Adenomera |           3466 |
# |  5 |              1 | Hypsiboas |            542 |
# | 11 |              2 | Hypsiboas |           1038 |
# | 19 |              3 | Ameerega  |            500 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | AdenomeraHylaedactylus |             3466 |
# |  5 |              1 | HypsiboasCinerascens   |              452 |
# | 13 |              2 | HypsiboasCordobae      |             1018 |
# | 23 |              3 | Ameeregatrivittata     |              500 |
#
#
# Hamming Loss obtained: 0.2224229789205467
# Hamming Score obtained: 0.7775770210794533
# Hamming Distance obtained: 0.66726893676164
# Hamming Distance Standard Deviation obtained: 1.206243709132836
# Monte Carlo Simulation Iteration: 6
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.3787509343305295
# For n_clusters=5, The Silhouette Coefficient is 0.3714828057802203
# For n_clusters=6, The Silhouette Coefficient is 0.264008021116715
# For n_clusters=7, The Silhouette Coefficient is 0.27088941333497224
# For n_clusters=8, The Silhouette Coefficient is 0.27012114209263827
# For n_clusters=9, The Silhouette Coefficient is 0.26153212403634274
# For n_clusters=10, The Silhouette Coefficient is 0.2636494732462223
# For n_clusters=11, The Silhouette Coefficient is 0.2616964787293548
# For n_clusters=12, The Silhouette Coefficient is 0.2743155711381428
# For n_clusters=13, The Silhouette Coefficient is 0.27800396569597385
# For n_clusters=14, The Silhouette Coefficient is 0.28070139350041134
# For n_clusters=15, The Silhouette Coefficient is 0.2702577845891809
# For n_clusters=16, The Silhouette Coefficient is 0.2599976191323615
# For n_clusters=17, The Silhouette Coefficient is 0.2636772959168412
# For n_clusters=18, The Silhouette Coefficient is 0.2808921552912572
# For n_clusters=19, The Silhouette Coefficient is 0.26533489733973437
# For n_clusters=20, The Silhouette Coefficient is 0.2732904115292595
# For n_clusters=21, The Silhouette Coefficient is 0.27038677173335574
# For n_clusters=22, The Silhouette Coefficient is 0.27690228020375085
# For n_clusters=23, The Silhouette Coefficient is 0.2657936743249676
# For n_clusters=24, The Silhouette Coefficient is 0.26602019974260827
# For n_clusters=25, The Silhouette Coefficient is 0.26306645385063304
# For n_clusters=26, The Silhouette Coefficient is 0.2659681821882419
# For n_clusters=27, The Silhouette Coefficient is 0.25994774249419
# For n_clusters=28, The Silhouette Coefficient is 0.2558011424164978
# For n_clusters=29, The Silhouette Coefficient is 0.2669322951465855
# For n_clusters=30, The Silhouette Coefficient is 0.2678251299440116
# For n_clusters=31, The Silhouette Coefficient is 0.257755074742884
# For n_clusters=32, The Silhouette Coefficient is 0.25852193726064554
# For n_clusters=33, The Silhouette Coefficient is 0.2576113974175393
# For n_clusters=34, The Silhouette Coefficient is 0.26801660914349756
# For n_clusters=35, The Silhouette Coefficient is 0.25714363122469003
# For n_clusters=36, The Silhouette Coefficient is 0.2650414970551168
# For n_clusters=37, The Silhouette Coefficient is 0.23933361480317975
# For n_clusters=38, The Silhouette Coefficient is 0.2634718491005244
# For n_clusters=39, The Silhouette Coefficient is 0.25492597382550475
# For n_clusters=40, The Silhouette Coefficient is 0.26864832179210596
# For n_clusters=41, The Silhouette Coefficient is 0.24937509701321042
# For n_clusters=42, The Silhouette Coefficient is 0.2407923494737051
# For n_clusters=43, The Silhouette Coefficient is 0.2504834175300578
# For n_clusters=44, The Silhouette Coefficient is 0.22318158593849888
# For n_clusters=45, The Silhouette Coefficient is 0.23262149973577245
# For n_clusters=46, The Silhouette Coefficient is 0.20916447658894535
# For n_clusters=47, The Silhouette Coefficient is 0.20992039444946242
# For n_clusters=48, The Silhouette Coefficient is 0.2144520119135613
# For n_clusters=49, The Silhouette Coefficient is 0.2060018128181973
# For n_clusters=50, The Silhouette Coefficient is 0.21251591081316193
# Best k is 4 based on highest Silhouette coefficient score: 0.3787509343305295
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Leptodactylidae |            3467 |
# |  2 |              1 | Hylidae         |             590 |
# |  5 |              2 | Dendrobatidae   |             500 |
# |  8 |              3 | Hylidae         |            1245 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Adenomera |           3466 |
# |  5 |              1 | Hypsiboas |            542 |
# | 11 |              2 | Ameerega  |            500 |
# | 17 |              3 | Hypsiboas |           1038 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | AdenomeraHylaedactylus |             3466 |
# |  5 |              1 | HypsiboasCinerascens   |              452 |
# | 13 |              2 | Ameeregatrivittata     |              500 |
# | 19 |              3 | HypsiboasCordobae      |             1018 |
#
#
# Hamming Loss obtained: 0.2224229789205467
# Hamming Score obtained: 0.7775770210794533
# Hamming Distance obtained: 0.66726893676164
# Hamming Distance Standard Deviation obtained: 1.206243709132836
# Monte Carlo Simulation Iteration: 7
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.3787509343305295
# For n_clusters=5, The Silhouette Coefficient is 0.3714828057802203
# For n_clusters=6, The Silhouette Coefficient is 0.264008021116715
# For n_clusters=7, The Silhouette Coefficient is 0.2606154509762368
# For n_clusters=8, The Silhouette Coefficient is 0.25462946544727455
# For n_clusters=9, The Silhouette Coefficient is 0.2759782814533313
# For n_clusters=10, The Silhouette Coefficient is 0.27446134491533164
# For n_clusters=11, The Silhouette Coefficient is 0.2648422462082135
# For n_clusters=12, The Silhouette Coefficient is 0.2722183775599109
# For n_clusters=13, The Silhouette Coefficient is 0.27822405347237156
# For n_clusters=14, The Silhouette Coefficient is 0.2648519815726346
# For n_clusters=15, The Silhouette Coefficient is 0.258051722998844
# For n_clusters=16, The Silhouette Coefficient is 0.27501772844012595
# For n_clusters=17, The Silhouette Coefficient is 0.26611524202396275
# For n_clusters=18, The Silhouette Coefficient is 0.28081554443913154
# For n_clusters=19, The Silhouette Coefficient is 0.27250278035947456
# For n_clusters=20, The Silhouette Coefficient is 0.2660569715303741
# For n_clusters=21, The Silhouette Coefficient is 0.26977922840306706
# For n_clusters=22, The Silhouette Coefficient is 0.27241562039472145
# For n_clusters=23, The Silhouette Coefficient is 0.26858073295071877
# For n_clusters=24, The Silhouette Coefficient is 0.27294028280697596
# For n_clusters=25, The Silhouette Coefficient is 0.26505105029042186
# For n_clusters=26, The Silhouette Coefficient is 0.2649926707033313
# For n_clusters=27, The Silhouette Coefficient is 0.2667776118976477
# For n_clusters=28, The Silhouette Coefficient is 0.2678704235098862
# For n_clusters=29, The Silhouette Coefficient is 0.24736404093636602
# For n_clusters=30, The Silhouette Coefficient is 0.264472487504729
# For n_clusters=31, The Silhouette Coefficient is 0.2639290482568409
# For n_clusters=32, The Silhouette Coefficient is 0.2653819093739544
# For n_clusters=33, The Silhouette Coefficient is 0.24160849918054536
# For n_clusters=34, The Silhouette Coefficient is 0.24090339810222755
# For n_clusters=35, The Silhouette Coefficient is 0.2549050674691388
# For n_clusters=36, The Silhouette Coefficient is 0.2532920404697768
# For n_clusters=37, The Silhouette Coefficient is 0.242243579391658
# For n_clusters=38, The Silhouette Coefficient is 0.2598714107805095
# For n_clusters=39, The Silhouette Coefficient is 0.2464842390440591
# For n_clusters=40, The Silhouette Coefficient is 0.25339403748434447
# For n_clusters=41, The Silhouette Coefficient is 0.22382038919080394
# For n_clusters=42, The Silhouette Coefficient is 0.2126120063701841
# For n_clusters=43, The Silhouette Coefficient is 0.2534017807399475
# For n_clusters=44, The Silhouette Coefficient is 0.22706634780584203
# For n_clusters=45, The Silhouette Coefficient is 0.2356524706836988
# For n_clusters=46, The Silhouette Coefficient is 0.23644058903537088
# For n_clusters=47, The Silhouette Coefficient is 0.24013096752536472
# For n_clusters=48, The Silhouette Coefficient is 0.2109426051014623
# For n_clusters=49, The Silhouette Coefficient is 0.21813095518200024
# For n_clusters=50, The Silhouette Coefficient is 0.21004221251996585
# Best k is 4 based on highest Silhouette coefficient score: 0.3787509343305295
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Hylidae         |            1245 |
# |  4 |              1 | Leptodactylidae |            3467 |
# |  6 |              2 | Dendrobatidae   |             501 |
# |  9 |              3 | Hylidae         |             590 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Hypsiboas |           1038 |
# |  8 |              1 | Adenomera |           3466 |
# | 13 |              2 | Ameerega  |            501 |
# | 19 |              3 | Hypsiboas |            542 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | HypsiboasCordobae      |             1018 |
# | 10 |              1 | AdenomeraHylaedactylus |             3466 |
# | 15 |              2 | Ameeregatrivittata     |              501 |
# | 21 |              3 | HypsiboasCinerascens   |              452 |
#
#
# Hamming Loss obtained: 0.22228399351401437
# Hamming Score obtained: 0.7777160064859856
# Hamming Distance obtained: 0.6668519805420431
# Hamming Distance Standard Deviation obtained: 1.2059557166933705
# Monte Carlo Simulation Iteration: 8
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.3787509343305295
# For n_clusters=5, The Silhouette Coefficient is 0.37149147864771287
# For n_clusters=6, The Silhouette Coefficient is 0.2644130229717876
# For n_clusters=7, The Silhouette Coefficient is 0.2708824275211291
# For n_clusters=8, The Silhouette Coefficient is 0.2701445428442861
# For n_clusters=9, The Silhouette Coefficient is 0.2639257049296656
# For n_clusters=10, The Silhouette Coefficient is 0.26259858917906165
# For n_clusters=11, The Silhouette Coefficient is 0.2690578442867476
# For n_clusters=12, The Silhouette Coefficient is 0.2720032759206621
# For n_clusters=13, The Silhouette Coefficient is 0.2782611143964412
# For n_clusters=14, The Silhouette Coefficient is 0.26573093646333557
# For n_clusters=15, The Silhouette Coefficient is 0.2891472172141786
# For n_clusters=16, The Silhouette Coefficient is 0.26655973670755156
# For n_clusters=17, The Silhouette Coefficient is 0.2661510432627228
# For n_clusters=18, The Silhouette Coefficient is 0.2683798588664592
# For n_clusters=19, The Silhouette Coefficient is 0.27802942866040176
# For n_clusters=20, The Silhouette Coefficient is 0.2775936868500849
# For n_clusters=21, The Silhouette Coefficient is 0.27035498683244985
# For n_clusters=22, The Silhouette Coefficient is 0.28654805434985187
# For n_clusters=23, The Silhouette Coefficient is 0.2685299001767938
# For n_clusters=24, The Silhouette Coefficient is 0.27071714021782
# For n_clusters=25, The Silhouette Coefficient is 0.26857680142771784
# For n_clusters=26, The Silhouette Coefficient is 0.27360465680486434
# For n_clusters=27, The Silhouette Coefficient is 0.2731689483922662
# For n_clusters=28, The Silhouette Coefficient is 0.2659260770257312
# For n_clusters=29, The Silhouette Coefficient is 0.26566902610017523
# For n_clusters=30, The Silhouette Coefficient is 0.26167571327495687
# For n_clusters=31, The Silhouette Coefficient is 0.26084956637934514
# For n_clusters=32, The Silhouette Coefficient is 0.261794825819069
# For n_clusters=33, The Silhouette Coefficient is 0.2634072045288163
# For n_clusters=34, The Silhouette Coefficient is 0.26497418607078577
# For n_clusters=35, The Silhouette Coefficient is 0.26019156841267876
# For n_clusters=36, The Silhouette Coefficient is 0.26271454554750834
# For n_clusters=37, The Silhouette Coefficient is 0.25429974280201345
# For n_clusters=38, The Silhouette Coefficient is 0.24199300067809823
# For n_clusters=39, The Silhouette Coefficient is 0.2458032346138942
# For n_clusters=40, The Silhouette Coefficient is 0.21741217897624524
# For n_clusters=41, The Silhouette Coefficient is 0.25672993585211523
# For n_clusters=42, The Silhouette Coefficient is 0.21696704639104672
# For n_clusters=43, The Silhouette Coefficient is 0.22895256771316755
# For n_clusters=44, The Silhouette Coefficient is 0.22277181884689926
# For n_clusters=45, The Silhouette Coefficient is 0.2307035243999135
# For n_clusters=46, The Silhouette Coefficient is 0.20205099984115343
# For n_clusters=47, The Silhouette Coefficient is 0.21488116745331165
# For n_clusters=48, The Silhouette Coefficient is 0.24428613262339116
# For n_clusters=49, The Silhouette Coefficient is 0.21920722528838907
# For n_clusters=50, The Silhouette Coefficient is 0.2171718224377744
# Best k is 4 based on highest Silhouette coefficient score: 0.3787509343305295
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Hylidae         |             590 |
# |  3 |              1 | Dendrobatidae   |             500 |
# |  6 |              2 | Leptodactylidae |            3467 |
# |  8 |              3 | Hylidae         |            1245 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Hypsiboas |            542 |
# |  6 |              1 | Ameerega  |            500 |
# | 12 |              2 | Adenomera |           3466 |
# | 17 |              3 | Hypsiboas |           1038 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | HypsiboasCinerascens   |              452 |
# |  8 |              1 | Ameeregatrivittata     |              500 |
# | 14 |              2 | AdenomeraHylaedactylus |             3466 |
# | 19 |              3 | HypsiboasCordobae      |             1018 |
#
#
# Hamming Loss obtained: 0.2224229789205467
# Hamming Score obtained: 0.7775770210794533
# Hamming Distance obtained: 0.66726893676164
# Hamming Distance Standard Deviation obtained: 1.206243709132836
# Monte Carlo Simulation Iteration: 9
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.3787509343305295
# For n_clusters=5, The Silhouette Coefficient is 0.37170236413433505
# For n_clusters=6, The Silhouette Coefficient is 0.264008021116715
# For n_clusters=7, The Silhouette Coefficient is 0.2605424786999264
# For n_clusters=8, The Silhouette Coefficient is 0.2701445428442861
# For n_clusters=9, The Silhouette Coefficient is 0.276225500089961
# For n_clusters=10, The Silhouette Coefficient is 0.2641754617334169
# For n_clusters=11, The Silhouette Coefficient is 0.2625978238197572
# For n_clusters=12, The Silhouette Coefficient is 0.2721473611366882
# For n_clusters=13, The Silhouette Coefficient is 0.27794591376491634
# For n_clusters=14, The Silhouette Coefficient is 0.2649894553387552
# For n_clusters=15, The Silhouette Coefficient is 0.2713558511306765
# For n_clusters=16, The Silhouette Coefficient is 0.29190618101814786
# For n_clusters=17, The Silhouette Coefficient is 0.27345341534647033
# For n_clusters=18, The Silhouette Coefficient is 0.2635251451279432
# For n_clusters=19, The Silhouette Coefficient is 0.270979628858682
# For n_clusters=20, The Silhouette Coefficient is 0.26016799879995484
# For n_clusters=21, The Silhouette Coefficient is 0.2628527066908722
# For n_clusters=22, The Silhouette Coefficient is 0.28500606242351023
# For n_clusters=23, The Silhouette Coefficient is 0.2735850070902643
# For n_clusters=24, The Silhouette Coefficient is 0.27297761489617145
# For n_clusters=25, The Silhouette Coefficient is 0.26222744776123397
# For n_clusters=26, The Silhouette Coefficient is 0.2718996587344492
# For n_clusters=27, The Silhouette Coefficient is 0.2637275477742911
# For n_clusters=28, The Silhouette Coefficient is 0.26584511209335526
# For n_clusters=29, The Silhouette Coefficient is 0.27689557217493366
# For n_clusters=30, The Silhouette Coefficient is 0.2654610203032796
# For n_clusters=31, The Silhouette Coefficient is 0.26188576452277834
# For n_clusters=32, The Silhouette Coefficient is 0.26669073058779524
# For n_clusters=33, The Silhouette Coefficient is 0.26679420445470525
# For n_clusters=34, The Silhouette Coefficient is 0.2607763371161618
# For n_clusters=35, The Silhouette Coefficient is 0.24664409089307318
# For n_clusters=36, The Silhouette Coefficient is 0.2657112706187703
# For n_clusters=37, The Silhouette Coefficient is 0.25030076711718807
# For n_clusters=38, The Silhouette Coefficient is 0.24134372827912348
# For n_clusters=39, The Silhouette Coefficient is 0.25768444918493044
# For n_clusters=40, The Silhouette Coefficient is 0.2217693690365028
# For n_clusters=41, The Silhouette Coefficient is 0.2415945853968293
# For n_clusters=42, The Silhouette Coefficient is 0.24048190857983526
# For n_clusters=43, The Silhouette Coefficient is 0.24213251742841002
# For n_clusters=44, The Silhouette Coefficient is 0.24027391809088153
# For n_clusters=45, The Silhouette Coefficient is 0.23625161025555105
# For n_clusters=46, The Silhouette Coefficient is 0.22757748135140557
# For n_clusters=47, The Silhouette Coefficient is 0.2127591334293776
# For n_clusters=48, The Silhouette Coefficient is 0.23293688556503092
# For n_clusters=49, The Silhouette Coefficient is 0.22154240897820549
# For n_clusters=50, The Silhouette Coefficient is 0.22455043524448182
# Best k is 4 based on highest Silhouette coefficient score: 0.3787509343305295
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Leptodactylidae |            3467 |
# |  2 |              1 | Dendrobatidae   |             504 |
# |  5 |              2 | Hylidae         |            1248 |
# |  9 |              3 | Hylidae         |             587 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Adenomera |           3466 |
# |  5 |              1 | Ameerega  |            504 |
# | 11 |              2 | Hypsiboas |           1040 |
# | 19 |              3 | Hypsiboas |            540 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | AdenomeraHylaedactylus |             3466 |
# |  5 |              1 | Ameeregatrivittata     |              504 |
# | 11 |              2 | HypsiboasCordobae      |             1020 |
# | 21 |              3 | HypsiboasCinerascens   |              452 |
#
#
# Hamming Loss obtained: 0.22177438035672922
# Hamming Score obtained: 0.7782256196432707
# Hamming Distance obtained: 0.6653231410701876
# Hamming Distance Standard Deviation obtained: 1.2051286315512202
# Monte Carlo Simulation Iteration: 10
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.3787509343305295
# For n_clusters=5, The Silhouette Coefficient is 0.37170236413433505
# For n_clusters=6, The Silhouette Coefficient is 0.2644568489306402
# For n_clusters=7, The Silhouette Coefficient is 0.2710721593378213
# For n_clusters=8, The Silhouette Coefficient is 0.27018500453263783
# For n_clusters=9, The Silhouette Coefficient is 0.26393715199884393
# For n_clusters=10, The Silhouette Coefficient is 0.2780019016350448
# For n_clusters=11, The Silhouette Coefficient is 0.27172821908571415
# For n_clusters=12, The Silhouette Coefficient is 0.27203057402355924
# For n_clusters=13, The Silhouette Coefficient is 0.2594674477015496
# For n_clusters=14, The Silhouette Coefficient is 0.2822515166755487
# For n_clusters=15, The Silhouette Coefficient is 0.2891273205848587
# For n_clusters=16, The Silhouette Coefficient is 0.27542098704123563
# For n_clusters=17, The Silhouette Coefficient is 0.26023743278373196
# For n_clusters=18, The Silhouette Coefficient is 0.27074222840293366
# For n_clusters=19, The Silhouette Coefficient is 0.28471708501399173
# For n_clusters=20, The Silhouette Coefficient is 0.3008375081772055
# For n_clusters=21, The Silhouette Coefficient is 0.269677661511491
# For n_clusters=22, The Silhouette Coefficient is 0.2684972400690756
# For n_clusters=23, The Silhouette Coefficient is 0.2749350878745277
# For n_clusters=24, The Silhouette Coefficient is 0.272227844641735
# For n_clusters=25, The Silhouette Coefficient is 0.277155540374364
# For n_clusters=26, The Silhouette Coefficient is 0.27170933520450485
# For n_clusters=27, The Silhouette Coefficient is 0.26627533451164875
# For n_clusters=28, The Silhouette Coefficient is 0.26024074649830264
# For n_clusters=29, The Silhouette Coefficient is 0.2706177567440882
# For n_clusters=30, The Silhouette Coefficient is 0.2637169225949252
# For n_clusters=31, The Silhouette Coefficient is 0.2640592475090536
# For n_clusters=32, The Silhouette Coefficient is 0.2635024821296433
# For n_clusters=33, The Silhouette Coefficient is 0.27031154736205354
# For n_clusters=34, The Silhouette Coefficient is 0.23985532461625386
# For n_clusters=35, The Silhouette Coefficient is 0.2648913219389108
# For n_clusters=36, The Silhouette Coefficient is 0.2401583671896063
# For n_clusters=37, The Silhouette Coefficient is 0.25942702197425754
# For n_clusters=38, The Silhouette Coefficient is 0.2571448420531686
# For n_clusters=39, The Silhouette Coefficient is 0.23947413389469138
# For n_clusters=40, The Silhouette Coefficient is 0.26046575542195904
# For n_clusters=41, The Silhouette Coefficient is 0.23869924165527703
# For n_clusters=42, The Silhouette Coefficient is 0.22357948660142088
# For n_clusters=43, The Silhouette Coefficient is 0.21715892383137667
# For n_clusters=44, The Silhouette Coefficient is 0.22210151080823548
# For n_clusters=45, The Silhouette Coefficient is 0.2580068666427277
# For n_clusters=46, The Silhouette Coefficient is 0.22530819478456854
# For n_clusters=47, The Silhouette Coefficient is 0.22989067455313633
# For n_clusters=48, The Silhouette Coefficient is 0.23610357514753783
# For n_clusters=49, The Silhouette Coefficient is 0.24439426643644696
# For n_clusters=50, The Silhouette Coefficient is 0.23688311582180957
# Best k is 4 based on highest Silhouette coefficient score: 0.3787509343305295
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Leptodactylidae |            3469 |
# |  2 |              1 | Hylidae         |            1060 |
# |  5 |              2 | Leptodactylidae |             588 |
# |  8 |              3 | Hylidae         |             897 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Adenomera |           3466 |
# |  5 |              1 | Hypsiboas |            946 |
# ...
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Leptodactylidae |             588 |
# |  3 |              1 | Leptodactylidae |            3469 |
# |  5 |              2 | Hylidae         |            1060 |
# |  8 |              3 | Hylidae         |             897 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Adenomera |            368 |
# |  7 |              1 | Adenomera |           3466 |
# | 12 |              2 | Hypsiboas |            946 |
# | 19 |              3 | Hypsiboas |            586 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | AdenomeraAndre         |              368 |
# |  8 |              1 | AdenomeraHylaedactylus |             3466 |
# | 13 |              2 | HypsiboasCordobae      |              494 |
# | 22 |              3 | HypsiboasCordobae      |              586 |
#
#
# Hamming Loss obtained: 0.24512392865415797
# Hamming Score obtained: 0.754876071345842
# Hamming Distance obtained: 0.735371785962474
# Hamming Distance Standard Deviation obtained: 1.1660895280330992
# Monte Carlo Simulation Iteration: 48
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.37863353074850936
# For n_clusters=5, The Silhouette Coefficient is 0.3714828057802203
# For n_clusters=6, The Silhouette Coefficient is 0.23774288894990356
# For n_clusters=7, The Silhouette Coefficient is 0.26046421061493086
# For n_clusters=8, The Silhouette Coefficient is 0.28049518861856554
# For n_clusters=9, The Silhouette Coefficient is 0.27608850666706064
# For n_clusters=10, The Silhouette Coefficient is 0.2612939847661176
# For n_clusters=11, The Silhouette Coefficient is 0.27134730934052204
# For n_clusters=12, The Silhouette Coefficient is 0.2727437684891449
# For n_clusters=13, The Silhouette Coefficient is 0.2778901773986054
# For n_clusters=14, The Silhouette Coefficient is 0.28096036522678736
# For n_clusters=15, The Silhouette Coefficient is 0.2699520490648571
# For n_clusters=16, The Silhouette Coefficient is 0.27449852215587334
# For n_clusters=17, The Silhouette Coefficient is 0.2733996574093953
# For n_clusters=18, The Silhouette Coefficient is 0.26569400595369236
# For n_clusters=19, The Silhouette Coefficient is 0.2774503961620574
# For n_clusters=20, The Silhouette Coefficient is 0.27024071154859663
# For n_clusters=21, The Silhouette Coefficient is 0.26271892572716515
# For n_clusters=22, The Silhouette Coefficient is 0.2765818623556585
# For n_clusters=23, The Silhouette Coefficient is 0.26938365328230074
# For n_clusters=24, The Silhouette Coefficient is 0.2608391716981502
# For n_clusters=25, The Silhouette Coefficient is 0.27284107922792084
# For n_clusters=26, The Silhouette Coefficient is 0.2714634288539091
# For n_clusters=27, The Silhouette Coefficient is 0.2678279677586385
# For n_clusters=28, The Silhouette Coefficient is 0.26832690471276566
# For n_clusters=29, The Silhouette Coefficient is 0.26478613751920266
# For n_clusters=30, The Silhouette Coefficient is 0.264039995692782
# For n_clusters=31, The Silhouette Coefficient is 0.2404901574869662
# For n_clusters=32, The Silhouette Coefficient is 0.2649542292178868
# For n_clusters=33, The Silhouette Coefficient is 0.26690738353808807
# For n_clusters=34, The Silhouette Coefficient is 0.26393936288060565
# For n_clusters=35, The Silhouette Coefficient is 0.24009716976870618
# For n_clusters=36, The Silhouette Coefficient is 0.25365076529509445
# For n_clusters=37, The Silhouette Coefficient is 0.25954483689457425
# For n_clusters=38, The Silhouette Coefficient is 0.24508662134432663
# For n_clusters=39, The Silhouette Coefficient is 0.2690234488283243
# For n_clusters=40, The Silhouette Coefficient is 0.25851483424011445
# For n_clusters=41, The Silhouette Coefficient is 0.24541108016384425
# For n_clusters=42, The Silhouette Coefficient is 0.25481898056566193
# For n_clusters=43, The Silhouette Coefficient is 0.2355876534038403
# For n_clusters=44, The Silhouette Coefficient is 0.23586720276177459
# For n_clusters=45, The Silhouette Coefficient is 0.24509964218236774
# For n_clusters=46, The Silhouette Coefficient is 0.21892570935039626
# For n_clusters=47, The Silhouette Coefficient is 0.2308740164439153
# For n_clusters=48, The Silhouette Coefficient is 0.25050417690347937
# For n_clusters=49, The Silhouette Coefficient is 0.23647894203317407
# For n_clusters=50, The Silhouette Coefficient is 0.21686971488509918
# Best k is 4 based on highest Silhouette coefficient score: 0.37863353074850936
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Hylidae         |             587 |
# |  3 |              1 | Leptodactylidae |            3467 |
# |  5 |              2 | Hylidae         |            1248 |
# |  9 |              3 | Dendrobatidae   |             504 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Hypsiboas |            540 |
# |  6 |              1 | Adenomera |           3466 |
# | 11 |              2 | Hypsiboas |           1040 |
# | 19 |              3 | Ameerega  |            504 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | HypsiboasCinerascens   |              452 |
# |  8 |              1 | AdenomeraHylaedactylus |             3466 |
# | 13 |              2 | HypsiboasCordobae      |             1020 |
# | 23 |              3 | Ameeregatrivittata     |              504 |
#
#
# Hamming Loss obtained: 0.22177438035672922
# Hamming Score obtained: 0.7782256196432707
# Hamming Distance obtained: 0.6653231410701876
# Hamming Distance Standard Deviation obtained: 1.2051286315512202
# Monte Carlo Simulation Iteration: 49
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.3787509343305295
# For n_clusters=5, The Silhouette Coefficient is 0.3714828057802203
# For n_clusters=6, The Silhouette Coefficient is 0.2644052337316085
# For n_clusters=7, The Silhouette Coefficient is 0.26069413132392916
# For n_clusters=8, The Silhouette Coefficient is 0.27043178624172043
# For n_clusters=9, The Silhouette Coefficient is 0.27618665711269547
# For n_clusters=10, The Silhouette Coefficient is 0.26221431590031313
# For n_clusters=11, The Silhouette Coefficient is 0.27140714739639976
# For n_clusters=12, The Silhouette Coefficient is 0.2737829812676105
# For n_clusters=13, The Silhouette Coefficient is 0.27768922966419557
# For n_clusters=14, The Silhouette Coefficient is 0.2650604211706711
# For n_clusters=15, The Silhouette Coefficient is 0.2705845955103341
# For n_clusters=16, The Silhouette Coefficient is 0.2760947481805496
# For n_clusters=17, The Silhouette Coefficient is 0.2655306595277004
# For n_clusters=18, The Silhouette Coefficient is 0.27721332646272623
# For n_clusters=19, The Silhouette Coefficient is 0.27014188850974236
# For n_clusters=20, The Silhouette Coefficient is 0.2725420631098677
# For n_clusters=21, The Silhouette Coefficient is 0.27415951395542815
# For n_clusters=22, The Silhouette Coefficient is 0.26629455949285924
# For n_clusters=23, The Silhouette Coefficient is 0.260842082610594
# For n_clusters=24, The Silhouette Coefficient is 0.27383058947953925
# For n_clusters=25, The Silhouette Coefficient is 0.2658220461588676
# For n_clusters=26, The Silhouette Coefficient is 0.2663187068333853
# For n_clusters=27, The Silhouette Coefficient is 0.25883308062774324
# For n_clusters=28, The Silhouette Coefficient is 0.2655599505545297
# For n_clusters=29, The Silhouette Coefficient is 0.2657046266303812
# For n_clusters=30, The Silhouette Coefficient is 0.24523186610405734
# For n_clusters=31, The Silhouette Coefficient is 0.26443898332930243
# For n_clusters=32, The Silhouette Coefficient is 0.2667386865683735
# For n_clusters=33, The Silhouette Coefficient is 0.25349446482878935
# For n_clusters=34, The Silhouette Coefficient is 0.2625899010076988
# For n_clusters=35, The Silhouette Coefficient is 0.2661475190925248
# For n_clusters=36, The Silhouette Coefficient is 0.24930695813671008
# For n_clusters=37, The Silhouette Coefficient is 0.24108013612418588
# For n_clusters=38, The Silhouette Coefficient is 0.25193104790025456
# For n_clusters=39, The Silhouette Coefficient is 0.257046352429235
# For n_clusters=40, The Silhouette Coefficient is 0.2345513181023655
# For n_clusters=41, The Silhouette Coefficient is 0.23996637105281599
# For n_clusters=42, The Silhouette Coefficient is 0.24072592708429558
# For n_clusters=43, The Silhouette Coefficient is 0.25104404598933217
# For n_clusters=44, The Silhouette Coefficient is 0.21916114377981302
# For n_clusters=45, The Silhouette Coefficient is 0.23853909102170082
# For n_clusters=46, The Silhouette Coefficient is 0.2503807132833829
# For n_clusters=47, The Silhouette Coefficient is 0.23597282142965087
# For n_clusters=48, The Silhouette Coefficient is 0.2241807710910927
# For n_clusters=49, The Silhouette Coefficient is 0.20733187132952624
# For n_clusters=50, The Silhouette Coefficient is 0.2099589817277723
# Best k is 4 based on highest Silhouette coefficient score: 0.3787509343305295
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Leptodactylidae |            3467 |
# |  2 |              1 | Hylidae         |            1245 |
# |  6 |              2 | Dendrobatidae   |             500 |
# |  9 |              3 | Hylidae         |             590 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Adenomera |           3466 |
# |  5 |              1 | Hypsiboas |           1038 |
# | 13 |              2 | Ameerega  |            500 |
# | 19 |              3 | Hypsiboas |            542 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | AdenomeraHylaedactylus |             3466 |
# |  5 |              1 | HypsiboasCordobae      |             1018 |
# | 15 |              2 | Ameeregatrivittata     |              500 |
# | 21 |              3 | HypsiboasCinerascens   |              452 |
#
#
# Hamming Loss obtained: 0.2224229789205467
# Hamming Score obtained: 0.7775770210794533
# Hamming Distance obtained: 0.66726893676164
# Hamming Distance Standard Deviation obtained: 1.206243709132836
# Monte Carlo Simulation Iteration: 50
# For n_clusters=1, The Silhouette Coefficient is 0
# For n_clusters=2, The Silhouette Coefficient is 0.3486778410277152
# For n_clusters=3, The Silhouette Coefficient is 0.36768245219926315
# For n_clusters=4, The Silhouette Coefficient is 0.37876308666591424
# For n_clusters=5, The Silhouette Coefficient is 0.3714828057802203
# For n_clusters=6, The Silhouette Coefficient is 0.26441520675915026
# For n_clusters=7, The Silhouette Coefficient is 0.26046421061493086
# For n_clusters=8, The Silhouette Coefficient is 0.28049518861856554
# For n_clusters=9, The Silhouette Coefficient is 0.2615816651500736
# For n_clusters=10, The Silhouette Coefficient is 0.2622951151857084
# For n_clusters=11, The Silhouette Coefficient is 0.2798102721303787
# For n_clusters=12, The Silhouette Coefficient is 0.272911262399795
# For n_clusters=13, The Silhouette Coefficient is 0.2707179002555736
# For n_clusters=14, The Silhouette Coefficient is 0.26524842381251923
# For n_clusters=15, The Silhouette Coefficient is 0.2707108447427487
# For n_clusters=16, The Silhouette Coefficient is 0.27564351719705216
# For n_clusters=17, The Silhouette Coefficient is 0.2731837198939961
# For n_clusters=18, The Silhouette Coefficient is 0.27068171466938395
# For n_clusters=19, The Silhouette Coefficient is 0.2773507979032512
# For n_clusters=20, The Silhouette Coefficient is 0.2778381146873646
# For n_clusters=21, The Silhouette Coefficient is 0.28417404147256237
# For n_clusters=22, The Silhouette Coefficient is 0.2768672742327186
# For n_clusters=23, The Silhouette Coefficient is 0.2756515041128835
# For n_clusters=24, The Silhouette Coefficient is 0.2723022839388267
# For n_clusters=25, The Silhouette Coefficient is 0.2652919310535646
# For n_clusters=26, The Silhouette Coefficient is 0.263551144271902
# For n_clusters=27, The Silhouette Coefficient is 0.2724908550886332
# For n_clusters=28, The Silhouette Coefficient is 0.26364856677214193
# For n_clusters=29, The Silhouette Coefficient is 0.26297203006281034
# For n_clusters=30, The Silhouette Coefficient is 0.26333624148916096
# For n_clusters=31, The Silhouette Coefficient is 0.2650741423001539
# For n_clusters=32, The Silhouette Coefficient is 0.2647166503124983
# For n_clusters=33, The Silhouette Coefficient is 0.2634590921655102
# For n_clusters=34, The Silhouette Coefficient is 0.25383584945048393
# For n_clusters=35, The Silhouette Coefficient is 0.2543665033923014
# For n_clusters=36, The Silhouette Coefficient is 0.2391027427197526
# For n_clusters=37, The Silhouette Coefficient is 0.2438659069139792
# For n_clusters=38, The Silhouette Coefficient is 0.24652315355891455
# For n_clusters=39, The Silhouette Coefficient is 0.2537020962538396
# For n_clusters=40, The Silhouette Coefficient is 0.25343505283667006
# For n_clusters=41, The Silhouette Coefficient is 0.2480121904565311
# For n_clusters=42, The Silhouette Coefficient is 0.24551600508451424
# For n_clusters=43, The Silhouette Coefficient is 0.26276994011283267
# For n_clusters=44, The Silhouette Coefficient is 0.23730053390916614
# For n_clusters=45, The Silhouette Coefficient is 0.23303556146109924
# For n_clusters=46, The Silhouette Coefficient is 0.2254144359022176
# For n_clusters=47, The Silhouette Coefficient is 0.2096505423093177
# For n_clusters=48, The Silhouette Coefficient is 0.21810816848954534
# For n_clusters=49, The Silhouette Coefficient is 0.1988252803524608
# For n_clusters=50, The Silhouette Coefficient is 0.23199709522784553
# Best k is 4 based on highest Silhouette coefficient score: 0.37876308666591424
# Family cluster majority
#
# |    |   kmeans_label | Family          |   kmeans_family |
# |---:|---------------:|:----------------|----------------:|
# |  0 |              0 | Hylidae         |            1245 |
# |  4 |              1 | Leptodactylidae |            3467 |
# |  6 |              2 | Dendrobatidae   |             500 |
# |  9 |              3 | Hylidae         |             590 |
#
#
# Genus cluster majority
#
# |    |   kmeans_label | Genus     |   kmeans_genus |
# |---:|---------------:|:----------|---------------:|
# |  0 |              0 | Hypsiboas |           1038 |
# |  8 |              1 | Adenomera |           3466 |
# | 13 |              2 | Ameerega  |            500 |
# | 19 |              3 | Hypsiboas |            542 |
#
#
# Species cluster majority
#
# |    |   kmeans_label | Species                |   kmeans_species |
# |---:|---------------:|:-----------------------|-----------------:|
# |  0 |              0 | HypsiboasCordobae      |             1018 |
# | 10 |              1 | AdenomeraHylaedactylus |             3466 |
# | 15 |              2 | Ameeregatrivittata     |              500 |
# | 21 |              3 | HypsiboasCinerascens   |              452 |
#
#
# Hamming Loss obtained: 0.2224229789205467
# Hamming Score obtained: 0.7775770210794533
# Hamming Distance obtained: 0.66726893676164
# Hamming Distance Standard Deviation obtained: 1.206243709132836

# %%
print("\n\n")
print("************** FINAL DATA AFTER 50 SIMULATIONS **************")
print("\n\n")

simulation_data = pd.DataFrame({'Hamming losses' : hamming_loss_dict, 'Hamming Scores' : hamming_score_dict
                                , 'Hamming Distances' : hamming_dist_dict, 'Hamming Distance Stddev' : hamming_dist_std_dict})

print(simulation_data.to_markdown())
print("\n\n")

print("Average Hamming loss: " + str(sum(hamming_loss_dict)/len(hamming_loss_dict)))
print("\n")
print("Average Hamming Score: " + str(sum(hamming_score_dict)/len(hamming_score_dict)))
print("\n")
print("Average Hamming Distance: " + str(sum(hamming_dist_dict)/len(hamming_dist_dict)))
print("\n")
print("Standard Deviation of Hamming Distance: " + str(simulation_data["Hamming Distances"].std()))
# Out:
# ************** FINAL DATA AFTER 50 SIMULATIONS **************
#
#
#
# |    |   Hamming losses |   Hamming Scores |   Hamming Distances |   Hamming Distance Stddev |
# |---:|-----------------:|-----------------:|--------------------:|--------------------------:|
# |  0 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# |  1 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# |  2 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# |  3 |         0.222469 |         0.777531 |            0.667408 |                   1.20622 |
# |  4 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# |  5 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# |  6 |         0.222284 |         0.777716 |            0.666852 |                   1.20596 |
# |  7 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# |  8 |         0.221774 |         0.778226 |            0.665323 |                   1.20513 |
# |  9 |         0.245124 |         0.754876 |            0.735372 |                   1.16609 |
# | 10 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 11 |         0.222191 |         0.777809 |            0.666574 |                   1.20599 |
# | 12 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 13 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 14 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 15 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 16 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 17 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 18 |         0.245263 |         0.754737 |            0.735789 |                   1.16636 |
# | 19 |         0.222469 |         0.777531 |            0.667408 |                   1.20622 |
# | 20 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 21 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 22 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 23 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 24 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 25 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 26 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 27 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 28 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 29 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 30 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 31 |         0.221774 |         0.778226 |            0.665323 |                   1.20513 |
# | 32 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 33 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 34 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 35 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 36 |         0.222469 |         0.777531 |            0.667408 |                   1.20622 |
# | 37 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 38 |         0.221774 |         0.778226 |            0.665323 |                   1.20513 |
# | 39 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 40 |         0.233866 |         0.766134 |            0.701598 |                   1.18736 |
# | 41 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 42 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 43 |         0.222145 |         0.777855 |            0.666435 |                   1.20567 |
# | 44 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 45 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 46 |         0.245124 |         0.754876 |            0.735372 |                   1.16609 |
# | 47 |         0.221774 |         0.778226 |            0.665323 |                   1.20513 |
# | 48 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
# | 49 |         0.222423 |         0.777577 |            0.667269 |                   1.20624 |
#
#
#
# Average Hamming loss: 0.22395459810053261
#
#
# Average Hamming Score: 0.7760454018994666
#
#
# Average Hamming Distance: 0.6718637943015986
#
#
# Standard Deviation of Hamming Distance: 0.0169695923084129

# %% [markdown]
# # 3. ISLR 12.6.2

# %% [markdown]
# ![Screen%20Shot%202022-11-08%20at%208.11.00%20PM.png](attachment:Screen%20Shot%202022-11-08%20at%208.11.00%20PM.png)

# %% [markdown]
# ##### Answer a
#
# ![an_1.jpg](attachment:an_1.jpg)

# %% [markdown]
# ##### Answer b
#
# ![bn_1.jpg](attachment:bn_1.jpg)

# %% [markdown]
# ##### Answer c
# Cluster 1 has 1, 2 <br>
# Cluster 2 has 3, 4 <br>
#
# ##### Answer d
# Cluster 1 has 1, 2, 3 <br>
# Cluster 2 has 4 <br>

# %% [markdown]
# ##### Answer e
#
# ![en_1.jpg](attachment:en_1.jpg)
